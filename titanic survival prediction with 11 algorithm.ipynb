# %%
import os
import numpy as np
import pandas as pd

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_theme(context='notebook',
              style='whitegrid',
              palette='rainbow',
              font='Lucida Calligraphy',
              font_scale=1.5,
              rc=None)
import matplotlib
matplotlib.rcParams['figure.figsize'] = [8, 8]
matplotlib.rcParams.update({'font.size': 15})
matplotlib.rcParams['font.family'] = 'sans-serif'

# %%
titanic = pd.read_csv('../titanic_merge/train.csv')
titanic.head().style.set_properties(
    **{
        'background-color': 'LightBlue',
        'color': 'Black',
        'border-color': 'darkblack'
    })
# Out:
# <style type="text/css">
# #T_16dd1_row0_col0, #T_16dd1_row0_col1, #T_16dd1_row0_col2, #T_16dd1_row0_col3, #T_16dd1_row0_col4, #T_16dd1_row0_col5, #T_16dd1_row0_col6, #T_16dd1_row0_col7, #T_16dd1_row0_col8, #T_16dd1_row0_col9, #T_16dd1_row0_col10, #T_16dd1_row0_col11, #T_16dd1_row1_col0, #T_16dd1_row1_col1, #T_16dd1_row1_col2, #T_16dd1_row1_col3, #T_16dd1_row1_col4, #T_16dd1_row1_col5, #T_16dd1_row1_col6, #T_16dd1_row1_col7, #T_16dd1_row1_col8, #T_16dd1_row1_col9, #T_16dd1_row1_col10, #T_16dd1_row1_col11, #T_16dd1_row2_col0, #T_16dd1_row2_col1, #T_16dd1_row2_col2, #T_16dd1_row2_col3, #T_16dd1_row2_col4, #T_16dd1_row2_col5, #T_16dd1_row2_col6, #T_16dd1_row2_col7, #T_16dd1_row2_col8, #T_16dd1_row2_col9, #T_16dd1_row2_col10, #T_16dd1_row2_col11, #T_16dd1_row3_col0, #T_16dd1_row3_col1, #T_16dd1_row3_col2, #T_16dd1_row3_col3, #T_16dd1_row3_col4, #T_16dd1_row3_col5, #T_16dd1_row3_col6, #T_16dd1_row3_col7, #T_16dd1_row3_col8, #T_16dd1_row3_col9, #T_16dd1_row3_col10, #T_16dd1_row3_col11, #T_16dd1_row4_col0, #T_16dd1_row4_col1, #T_16dd1_row4_col2, #T_16dd1_row4_col3, #T_16dd1_row4_col4, #T_16dd1_row4_col5, #T_16dd1_row4_col6, #T_16dd1_row4_col7, #T_16dd1_row4_col8, #T_16dd1_row4_col9, #T_16dd1_row4_col10, #T_16dd1_row4_col11 {
#   background-color: LightBlue;
#   color: Black;
#   border-color: darkblack;
# }
# </style>
# <table id="T_16dd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16dd1_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_16dd1_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_16dd1_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_16dd1_level0_col3" class="col_heading level0 col3" >Name</th>
#       <th id="T_16dd1_level0_col4" class="col_heading level0 col4" >Sex</th>
#       <th id="T_16dd1_level0_col5" class="col_heading level0 col5" >Age</th>
#       <th id="T_16dd1_level0_col6" class="col_heading level0 col6" >SibSp</th>
#       <th id="T_16dd1_level0_col7" class="col_heading level0 col7" >Parch</th>
#       <th id="T_16dd1_level0_col8" class="col_heading level0 col8" >Ticket</th>
#       <th id="T_16dd1_level0_col9" class="col_heading level0 col9" >Fare</th>
#       <th id="T_16dd1_level0_col10" class="col_heading level0 col10" >Cabin</th>
#       <th id="T_16dd1_level0_col11" class="col_heading level0 col11" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16dd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16dd1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_16dd1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_16dd1_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_16dd1_row0_col3" class="data row0 col3" >Braund, Mr. Owen Harris</td>
#       <td id="T_16dd1_row0_col4" class="data row0 col4" >male</td>
#       <td id="T_16dd1_row0_col5" class="data row0 col5" >22.000000</td>
#       <td id="T_16dd1_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_16dd1_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_16dd1_row0_col8" class="data row0 col8" >A/5 21171</td>
#       <td id="T_16dd1_row0_col9" class="data row0 col9" >7.250000</td>
#       <td id="T_16dd1_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_16dd1_row0_col11" class="data row0 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_16dd1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16dd1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_16dd1_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_16dd1_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_16dd1_row1_col3" class="data row1 col3" >Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td id="T_16dd1_row1_col4" class="data row1 col4" >female</td>
#       <td id="T_16dd1_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_16dd1_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_16dd1_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_16dd1_row1_col8" class="data row1 col8" >PC 17599</td>
#       <td id="T_16dd1_row1_col9" class="data row1 col9" >71.283300</td>
#       <td id="T_16dd1_row1_col10" class="data row1 col10" >C85</td>
#       <td id="T_16dd1_row1_col11" class="data row1 col11" >C</td>
#     </tr>
#     <tr>
#       <th id="T_16dd1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16dd1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_16dd1_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_16dd1_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_16dd1_row2_col3" class="data row2 col3" >Heikkinen, Miss. Laina</td>
#       <td id="T_16dd1_row2_col4" class="data row2 col4" >female</td>
#       <td id="T_16dd1_row2_col5" class="data row2 col5" >26.000000</td>
#       <td id="T_16dd1_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_16dd1_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_16dd1_row2_col8" class="data row2 col8" >STON/O2. 3101282</td>
#       <td id="T_16dd1_row2_col9" class="data row2 col9" >7.925000</td>
#       <td id="T_16dd1_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_16dd1_row2_col11" class="data row2 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_16dd1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16dd1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_16dd1_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_16dd1_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_16dd1_row3_col3" class="data row3 col3" >Futrelle, Mrs. Jacques Heath (Lily May Peel)</td>
#       <td id="T_16dd1_row3_col4" class="data row3 col4" >female</td>
#       <td id="T_16dd1_row3_col5" class="data row3 col5" >35.000000</td>
#       <td id="T_16dd1_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_16dd1_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_16dd1_row3_col8" class="data row3 col8" >113803</td>
#       <td id="T_16dd1_row3_col9" class="data row3 col9" >53.100000</td>
#       <td id="T_16dd1_row3_col10" class="data row3 col10" >C123</td>
#       <td id="T_16dd1_row3_col11" class="data row3 col11" >S</td>
#     </tr>
#     <tr>
#       <th id="T_16dd1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16dd1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_16dd1_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_16dd1_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_16dd1_row4_col3" class="data row4 col3" >Allen, Mr. William Henry</td>
#       <td id="T_16dd1_row4_col4" class="data row4 col4" >male</td>
#       <td id="T_16dd1_row4_col5" class="data row4 col5" >35.000000</td>
#       <td id="T_16dd1_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_16dd1_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_16dd1_row4_col8" class="data row4 col8" >373450</td>
#       <td id="T_16dd1_row4_col9" class="data row4 col9" >8.050000</td>
#       <td id="T_16dd1_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_16dd1_row4_col11" class="data row4 col11" >S</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('Shape of Titanic data set is :',titanic.shape)
print('Size of Titanic data set is  :',titanic.size)
# Out:
# Shape of Titanic data set is : (891, 12)
# Size of Titanic data set is  : 10692

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
matplotlib.rcParams.update({'font.size': 30})

titanic.dtypes.value_counts().plot.pie(explode=[0.1, 0.1, 0.1],
                                       autopct='%1.2f%%',
                                       shadow=True)
plt.title('Data Type',
          color='Green',
          loc='center',
          font='Lucida Calligraphy');

# %%
ax = sns.set(style="whitegrid")
ax = sns.countplot(data=titanic,x='Embarked');
ax.bar_label(ax.containers[0])

plt.title('Embarked Distribution',color='Red',loc='center',font='Lucida Calligraphy');
plt.xlabel('Embarked',color='Green',loc='center',font='Lucida Calligraphy')
plt.ylabel('Count',color='Red',loc='center',font='Lucida Calligraphy');

# %%
matplotlib.rcParams.update({'font.size': 30})
titanic['Embarked'].value_counts().plot.pie(explode=[0.1, 0.1, 0.1],
                                     autopct='%1.2f%%',
                                     shadow=True)
plt.title('Embarked Distribution',color='Red',loc='center');

# %%
matplotlib.rcParams.update({'font.size': 30})
titanic['Sex'].value_counts().plot.pie(explode=[0.1, 0.1],
                                     autopct='%1.2f%%',
                                     shadow=True)
plt.title('Gender Distribution',color='Red',loc='center');

# %%
matplotlib.rcParams.update({'font.size': 30})
titanic['Survived'].value_counts().plot.pie(explode=[0.1, 0.1],
                                     autopct='%1.2f%%',
                                     shadow=True)
plt.title('Survived',color='Red',loc='center');

# %%
titanic.corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <style type="text/css">
# #T_1b4cb_row0_col0, #T_1b4cb_row1_col1, #T_1b4cb_row2_col2, #T_1b4cb_row3_col3, #T_1b4cb_row4_col4, #T_1b4cb_row5_col5, #T_1b4cb_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1b4cb_row0_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_1b4cb_row0_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_1b4cb_row0_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1b4cb_row0_col4, #T_1b4cb_row3_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1b4cb_row0_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1b4cb_row0_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_1b4cb_row1_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1b4cb_row1_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_1b4cb_row1_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_1b4cb_row1_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1b4cb_row1_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1b4cb_row1_col6 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_1b4cb_row2_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1b4cb_row2_col1, #T_1b4cb_row2_col3, #T_1b4cb_row2_col6, #T_1b4cb_row3_col4, #T_1b4cb_row3_col5, #T_1b4cb_row4_col0, #T_1b4cb_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1b4cb_row2_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_1b4cb_row2_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1b4cb_row3_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1b4cb_row3_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1b4cb_row3_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_1b4cb_row4_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_1b4cb_row4_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1b4cb_row4_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1b4cb_row4_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_1b4cb_row4_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_1b4cb_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1b4cb_row5_col1 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_1b4cb_row5_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1b4cb_row5_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_1b4cb_row5_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_1b4cb_row5_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1b4cb_row6_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1b4cb_row6_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_1b4cb_row6_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_1b4cb_row6_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1b4cb_row6_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# </style>
# <table id="T_1b4cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b4cb_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_1b4cb_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_1b4cb_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_1b4cb_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_1b4cb_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_1b4cb_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_1b4cb_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b4cb_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_1b4cb_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_1b4cb_row0_col1" class="data row0 col1" >-0.005</td>
#       <td id="T_1b4cb_row0_col2" class="data row0 col2" >-0.035</td>
#       <td id="T_1b4cb_row0_col3" class="data row0 col3" >0.037</td>
#       <td id="T_1b4cb_row0_col4" class="data row0 col4" >-0.058</td>
#       <td id="T_1b4cb_row0_col5" class="data row0 col5" >-0.002</td>
#       <td id="T_1b4cb_row0_col6" class="data row0 col6" >0.013</td>
#     </tr>
#     <tr>
#       <th id="T_1b4cb_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_1b4cb_row1_col0" class="data row1 col0" >-0.005</td>
#       <td id="T_1b4cb_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_1b4cb_row1_col2" class="data row1 col2" >-0.338</td>
#       <td id="T_1b4cb_row1_col3" class="data row1 col3" >-0.077</td>
#       <td id="T_1b4cb_row1_col4" class="data row1 col4" >-0.035</td>
#       <td id="T_1b4cb_row1_col5" class="data row1 col5" >0.082</td>
#       <td id="T_1b4cb_row1_col6" class="data row1 col6" >0.257</td>
#     </tr>
#     <tr>
#       <th id="T_1b4cb_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_1b4cb_row2_col0" class="data row2 col0" >-0.035</td>
#       <td id="T_1b4cb_row2_col1" class="data row2 col1" >-0.338</td>
#       <td id="T_1b4cb_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_1b4cb_row2_col3" class="data row2 col3" >-0.369</td>
#       <td id="T_1b4cb_row2_col4" class="data row2 col4" >0.083</td>
#       <td id="T_1b4cb_row2_col5" class="data row2 col5" >0.018</td>
#       <td id="T_1b4cb_row2_col6" class="data row2 col6" >-0.549</td>
#     </tr>
#     <tr>
#       <th id="T_1b4cb_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_1b4cb_row3_col0" class="data row3 col0" >0.037</td>
#       <td id="T_1b4cb_row3_col1" class="data row3 col1" >-0.077</td>
#       <td id="T_1b4cb_row3_col2" class="data row3 col2" >-0.369</td>
#       <td id="T_1b4cb_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_1b4cb_row3_col4" class="data row3 col4" >-0.308</td>
#       <td id="T_1b4cb_row3_col5" class="data row3 col5" >-0.189</td>
#       <td id="T_1b4cb_row3_col6" class="data row3 col6" >0.096</td>
#     </tr>
#     <tr>
#       <th id="T_1b4cb_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_1b4cb_row4_col0" class="data row4 col0" >-0.058</td>
#       <td id="T_1b4cb_row4_col1" class="data row4 col1" >-0.035</td>
#       <td id="T_1b4cb_row4_col2" class="data row4 col2" >0.083</td>
#       <td id="T_1b4cb_row4_col3" class="data row4 col3" >-0.308</td>
#       <td id="T_1b4cb_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_1b4cb_row4_col5" class="data row4 col5" >0.415</td>
#       <td id="T_1b4cb_row4_col6" class="data row4 col6" >0.160</td>
#     </tr>
#     <tr>
#       <th id="T_1b4cb_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_1b4cb_row5_col0" class="data row5 col0" >-0.002</td>
#       <td id="T_1b4cb_row5_col1" class="data row5 col1" >0.082</td>
#       <td id="T_1b4cb_row5_col2" class="data row5 col2" >0.018</td>
#       <td id="T_1b4cb_row5_col3" class="data row5 col3" >-0.189</td>
#       <td id="T_1b4cb_row5_col4" class="data row5 col4" >0.415</td>
#       <td id="T_1b4cb_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_1b4cb_row5_col6" class="data row5 col6" >0.216</td>
#     </tr>
#     <tr>
#       <th id="T_1b4cb_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_1b4cb_row6_col0" class="data row6 col0" >0.013</td>
#       <td id="T_1b4cb_row6_col1" class="data row6 col1" >0.257</td>
#       <td id="T_1b4cb_row6_col2" class="data row6 col2" >-0.549</td>
#       <td id="T_1b4cb_row6_col3" class="data row6 col3" >0.096</td>
#       <td id="T_1b4cb_row6_col4" class="data row6 col4" >0.160</td>
#       <td id="T_1b4cb_row6_col5" class="data row6 col5" >0.216</td>
#       <td id="T_1b4cb_row6_col6" class="data row6 col6" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr=titanic.corr()#["Survived"]
plt.figure(figsize=(20, 15))
sns.heatmap(corr, vmax=.8, linewidths=0.01, square=True,annot=True,cmap='YlGnBu',linecolor="black")
plt.title('Correlation between features')
plt.show()

# %%
# correlation heatmap of higly correlated features with SalePrice
hig_corr = titanic.corr()
hig_corr_features = hig_corr.index[abs(hig_corr["Fare"]) >= 0.25]
hig_corr_features
# Out:
# Index(['Survived', 'Pclass', 'Fare'], dtype='object')

# %%
plt.figure(figsize=(10,8))
ax = sns.heatmap(titanic[hig_corr_features].corr(), cmap = "coolwarm", annot=True, linewidth=3)
# to fix the bug "first and last row cut in half of heatmap plot"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
g = sns.FacetGrid(titanic, col="Pclass")
g = g.map(plt.hist, "Age")

# %%
# Methods to find Missing Values

def missing_value (df):
    missing_Number = df.isnull().sum().sort_values(ascending=False)[df.isnull().sum().sort_values(ascending=False) !=0]
    missing_percent=round((df.isnull().sum()/df.isnull().count())*100,2)[round((df.isnull().sum()/df.isnull().count())*100,2) !=0]
    missing = pd.concat([missing_Number,missing_percent],axis=1,keys=['Missing Number','Missing Percentage'])
    return missing

# %%
missing_value(titanic).style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_1ea4e_row0_col0, #T_1ea4e_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1ea4e_row1_col0, #T_1ea4e_row1_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_1ea4e_row2_col0, #T_1ea4e_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1ea4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ea4e_level0_col0" class="col_heading level0 col0" >Missing Number</th>
#       <th id="T_1ea4e_level0_col1" class="col_heading level0 col1" >Missing Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ea4e_level0_row0" class="row_heading level0 row0" >Cabin</th>
#       <td id="T_1ea4e_row0_col0" class="data row0 col0" >687</td>
#       <td id="T_1ea4e_row0_col1" class="data row0 col1" >77.10</td>
#     </tr>
#     <tr>
#       <th id="T_1ea4e_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_1ea4e_row1_col0" class="data row1 col0" >177</td>
#       <td id="T_1ea4e_row1_col1" class="data row1 col1" >19.87</td>
#     </tr>
#     <tr>
#       <th id="T_1ea4e_level0_row2" class="row_heading level0 row2" >Embarked</th>
#       <td id="T_1ea4e_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_1ea4e_row2_col1" class="data row2 col1" >0.22</td>
#     </tr>
#   </tbody>
# </table>

# %%
missing_values = titanic.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values.sort_values(inplace=True)
missing_values.plot.pie(explode=[0.1, 0.1, 0.1],
                        autopct='%1.2f%%',
                        shadow=True)

plt.title('Missing Values',
          color='Green',
          loc='center',
          font='Lucida Calligraphy');

# %%
sns.heatmap(titanic.isnull(),cmap='cool');

# %%
# Feature Engineering

titanic['Age'] = titanic['Age'].fillna(titanic['Age'].mean())

# %%
titanic[titanic['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
titanic['Embarked'] = titanic['Embarked'].fillna(method='bfill')

# %%
titanic = titanic.drop(['Cabin'],axis=1)

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic = titanic.drop(['Name','Ticket'],axis=1)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
titanic = pd.get_dummies(titanic,columns=['Sex','Embarked'],drop_first=True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  \
# 0            1         0       3  22.0      1      0   7.2500         1
# 1            2         1       1  38.0      1      0  71.2833         0
# 2            3         1       3  26.0      0      0   7.9250         0
# 3            4         1       1  35.0      1      0  53.1000         0
# 4            5         0       3  35.0      0      0   8.0500         1
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
#train test split

X = titanic.drop(['Survived'],axis=1) 
y = titanic['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=21)

# %%
#Standardizing the data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train = pd.DataFrame(X_train, columns=X.columns)
X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
display(X_train.head())
display(X_test.head())
# Out:
#    PassengerId    Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# 0     1.360492 -1.584396  0.010681 -0.479698 -0.460682 -0.018600  0.728823
# 1    -1.632266 -1.584396 -0.119643 -0.479698 -0.460682  0.079245  0.728823
# 2    -1.344650 -1.584396 -0.503148 -0.479698  0.810657  0.646624  0.728823
# 3    -1.686680 -0.381742 -1.193456  0.493365 -0.460682 -0.031329 -1.372075
# 4    -1.111449  0.820913  0.033758 -0.479698 -0.460682 -0.479818  0.728823
#
#    Embarked_Q  Embarked_S
# 0   -0.311564   -1.611198
# 1   -0.311564    0.620656
# 2   -0.311564   -1.611198
# 3   -0.311564   -1.611198
# 4   -0.311564    0.620656
#    PassengerId    Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# 0     0.676433  0.820913 -0.273045  0.493365 -0.460682 -0.315867 -1.372075
# 1    -0.248601  0.820913 -0.809952 -0.479698 -0.460682 -0.485419  0.728823
# 2     1.096196  0.820913 -0.733251 -0.479698 -0.460682 -0.467343  0.728823
# 3     1.488753  0.820913  0.010681 -0.479698 -0.460682  0.506858  0.728823
# 4     0.027354 -0.381742  0.493964  0.493365  2.081997 -0.078596  0.728823
#
#    Embarked_Q  Embarked_S
# 0   -0.311564    0.620656
# 1   -0.311564    0.620656
# 2   -0.311564    0.620656
# 3   -0.311564    0.620656
# 4   -0.311564    0.620656

# %%
from sklearn.metrics import accuracy_score
# Logistic Regression

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
Y_pred = logreg.predict(X_test)

log_train = round(logreg.score(X_train, y_train) * 100, 2)
log_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy    :",log_train)
print("Model Accuracy Score :",log_accuracy)
# Out:
# Training Accuracy    : 80.2
# Model Accuracy Score : 79.89

# %%
# Support Vector Machines

from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
Y_pred = svc.predict(X_test)

svc_train = round(svc.score(X_train, y_train) * 100, 2)
svc_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",svc_train)
print("Model Accuracy Score  :",svc_accuracy)
# Out:
# Training Accuracy     : 85.11
# Model Accuracy Score  : 80.45

# %%
# KNeighborsClassifier

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
Y_pred = knn.predict(X_test)

knn_train = round(knn.score(X_train, y_train) * 100, 2)
knn_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",knn_train)
print("Model Accuracy Score  :",knn_accuracy)
# Out:
# Training Accuracy     : 90.03
# Model Accuracy Score  : 75.98

# %%
# Gaussian Naive Bayes

from sklearn.naive_bayes import GaussianNB
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_test)

gaussian_train = round(gaussian.score(X_train, y_train) * 100, 2)
gaussian_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",gaussian_train)
print("Model Accuracy Score  :",gaussian_accuracy)
# Out:
# Training Accuracy     : 79.21
# Model Accuracy Score  : 81.56

# %%
# Perceptron

from sklearn.linear_model import Perceptron
perceptron = Perceptron()
perceptron.fit(X_train, y_train)
Y_pred = perceptron.predict(X_test)


perceptron_train = round(perceptron.score(X_train, y_train) * 100, 2)
perceptron_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy    :",perceptron_train)
print("Model Accuracy Score :",perceptron_accuracy)
# Out:
# Training Accuracy    : 73.17
# Model Accuracy Score : 72.07

# %%
# Linear SVC

from sklearn.svm import LinearSVC
linear_svc = LinearSVC()
linear_svc.fit(X_train, y_train)
Y_pred = linear_svc.predict(X_test)

linear_svc_train = round(linear_svc.score(X_train, y_train) * 100, 2)
linear_svc_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy    :",linear_svc_train)
print("Model Accuracy Score :",linear_svc_accuracy)
# Out:
# Training Accuracy    : 80.34
# Model Accuracy Score : 80.45

# %%
# Stochastic Gradient Descent

from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier()
sgd.fit(X_train, y_train)
Y_pred = sgd.predict(X_test)

sgd_train = round(sgd.score(X_train, y_train) * 100, 2)
sgd_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",sgd_train)
print("Model Accuracy Score  :",sgd_accuracy)
# Out:
# Training Accuracy     : 75.84
# Model Accuracy Score  : 82.12

# %%
# Decision Tree

from sklearn.tree import DecisionTreeClassifier
decision = DecisionTreeClassifier()
decision.fit(X_train, y_train)
Y_pred = decision.predict(X_test)

decision_train = round(decision.score(X_train, y_train) * 100, 2)
decision_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",decision_train)
print("Model Accuracy Score  :",decision_accuracy)
# Out:
# Training Accuracy     : 100.0
# Model Accuracy Score  : 71.51

# %%
# Random Forest

from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
Y_pred = random_forest.predict(X_test)
random_forest.score(X_train, y_train)

random_forest_train = round(random_forest.score(X_train, y_train) * 100, 2)
random_forest_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",random_forest_train)
print("Model Accuracy Score  :",random_forest_accuracy)
# Out:
# Training Accuracy     : 100.0
# Model Accuracy Score  : 80.45

# %%
# MLPClassifier

from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier()
mlp.fit(X_train,y_train)
Y_pred = mlp.predict(X_test)
mlp.score(X_train, y_train)


mlp_train = round(mlp.score(X_train, y_train) * 100, 2)
mlp_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",mlp_train)
print("Model Accuracy Score  :",mlp_accuracy)
# Out:
# Training Accuracy     : 86.38
# Model Accuracy Score  : 79.89

# %%
import os
import os.path
from subprocess import Popen, PIPE
import sys
from threading import Thread
from urllib.parse import urlparse
from urllib.request import urlretrieve
import venv
import sys

# %%
# XGBClassifier
import xgboost as Xgb
xgb = Xgb.XGBClassifier()
xgb.fit(X_train,y_train)
Y_pred = xgb.predict(X_test)
xgb.score(X_train, y_train)

xgb_train = round(xgb.score(X_train, y_train) * 100, 2)
xgb_accuracy = round(accuracy_score(Y_pred, y_test) * 100, 2)

print("Training Accuracy     :",xgb_train)
print("Model Accuracy Score  :",xgb_accuracy)
# Out:
# Training Accuracy     : 100.0
# Model Accuracy Score  : 77.65

# %%
###   Comparing Models     ###
models = pd.DataFrame({
    'Model': [
        'Support Vector Machines', 'KNN', 'Logistic Regression',
        'Random Forest',  'Perceptron',
        'Stochastic Gradient Decent', 'Linear SVC', 'Decision Tree',
        'GaussianNB', 'MLPClassifier', 'XGBClassifier'
    ],
    'Training Accuracy': [
        log_train, svc_train, knn_train, gaussian_train, perceptron_train,
        linear_svc_train, sgd_train, decision_train, random_forest_train,
        mlp_train, xgb_train
    ],
    'Model Accuracy Score': [
        log_accuracy, svc_accuracy, knn_accuracy, gaussian_accuracy, perceptron_accuracy,
        linear_svc_accuracy, sgd_accuracy, decision_accuracy, random_forest_accuracy,
        mlp_accuracy, xgb_accuracy
    ]
})

# %%
models.sort_values(by='Training Accuracy', ascending=False)
# Out:
#                          Model  Training Accuracy  Model Accuracy Score
# 7                Decision Tree             100.00                 71.51
# 8                   GaussianNB             100.00                 80.45
# 10               XGBClassifier             100.00                 77.65
# 2          Logistic Regression              90.03                 75.98
# 9                MLPClassifier              86.38                 79.89
# 1                          KNN              85.11                 80.45
# 5   Stochastic Gradient Decent              80.34                 80.45
# 0      Support Vector Machines              80.20                 79.89
# 3                Random Forest              79.21                 81.56
# 6                   Linear SVC              75.84                 82.12
# 4                   Perceptron              73.17                 72.07

# %%
models.sort_values(by='Model Accuracy Score', ascending=False).style.background_gradient(
        cmap='coolwarm').hide_index().set_properties(**{
            'font-family': 'Lucida Calligraphy',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_87a56_row0_col0, #T_87a56_row1_col0, #T_87a56_row2_col0, #T_87a56_row3_col0, #T_87a56_row4_col0, #T_87a56_row5_col0, #T_87a56_row6_col0, #T_87a56_row7_col0, #T_87a56_row8_col0, #T_87a56_row9_col0, #T_87a56_row10_col0 {
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row0_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row0_col2, #T_87a56_row4_col1, #T_87a56_row7_col1, #T_87a56_row10_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row1_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row1_col2 {
#   background-color: #c73635;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row2_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row2_col2, #T_87a56_row3_col2, #T_87a56_row4_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row3_col1 {
#   background-color: #93b5fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row5_col1 {
#   background-color: #92b4fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row5_col2, #T_87a56_row6_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row6_col1 {
#   background-color: #dbdcde;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row7_col2 {
#   background-color: #efcfbf;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row8_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row8_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row9_col1, #T_87a56_row10_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_87a56_row9_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_87a56">
#   <thead>
#     <tr>
#       <th id="T_87a56_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87a56_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_87a56_level0_col2" class="col_heading level0 col2" >Model Accuracy Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87a56_row0_col0" class="data row0 col0" >Linear SVC</td>
#       <td id="T_87a56_row0_col1" class="data row0 col1" >75.840000</td>
#       <td id="T_87a56_row0_col2" class="data row0 col2" >82.120000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_87a56_row1_col1" class="data row1 col1" >79.210000</td>
#       <td id="T_87a56_row1_col2" class="data row1 col2" >81.560000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T_87a56_row2_col1" class="data row2 col1" >85.110000</td>
#       <td id="T_87a56_row2_col2" class="data row2 col2" >80.450000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row3_col0" class="data row3 col0" >Stochastic Gradient Decent</td>
#       <td id="T_87a56_row3_col1" class="data row3 col1" >80.340000</td>
#       <td id="T_87a56_row3_col2" class="data row3 col2" >80.450000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row4_col0" class="data row4 col0" >GaussianNB</td>
#       <td id="T_87a56_row4_col1" class="data row4 col1" >100.000000</td>
#       <td id="T_87a56_row4_col2" class="data row4 col2" >80.450000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row5_col0" class="data row5 col0" >Support Vector Machines</td>
#       <td id="T_87a56_row5_col1" class="data row5 col1" >80.200000</td>
#       <td id="T_87a56_row5_col2" class="data row5 col2" >79.890000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row6_col0" class="data row6 col0" >MLPClassifier</td>
#       <td id="T_87a56_row6_col1" class="data row6 col1" >86.380000</td>
#       <td id="T_87a56_row6_col2" class="data row6 col2" >79.890000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row7_col0" class="data row7 col0" >XGBClassifier</td>
#       <td id="T_87a56_row7_col1" class="data row7 col1" >100.000000</td>
#       <td id="T_87a56_row7_col2" class="data row7 col2" >77.650000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row8_col0" class="data row8 col0" >Logistic Regression</td>
#       <td id="T_87a56_row8_col1" class="data row8 col1" >90.030000</td>
#       <td id="T_87a56_row8_col2" class="data row8 col2" >75.980000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row9_col0" class="data row9 col0" >Perceptron</td>
#       <td id="T_87a56_row9_col1" class="data row9 col1" >73.170000</td>
#       <td id="T_87a56_row9_col2" class="data row9 col2" >72.070000</td>
#     </tr>
#     <tr>
#       <td id="T_87a56_row10_col0" class="data row10 col0" >Decision Tree</td>
#       <td id="T_87a56_row10_col1" class="data row10 col1" >100.000000</td>
#       <td id="T_87a56_row10_col2" class="data row10 col2" >71.510000</td>
#     </tr>
#   </tbody>
# </table>

# %%
models=models.sort_values(by='Model Accuracy Score',ascending=False)[:20]

sns.barplot(y= 'Model', x= 'Model Accuracy Score', data= models)
plt.title('COMPARE THE MODEL')
plt.xlabel('MODEL')
plt.ylabel('Training Accuracy');
